# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("kidney_disease.csv")

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.shape
# Out:
# (400, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
# In any EDA if a column is of no use then just drop the column
df.drop("id", axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.columns=["age","blood_pressure","specific_gravity","albumin","sugar","red_blood_cells","pus_cell","pus_cell_clumps","bacteria","blood_glucose_level",
            "blood_urea","serum_creatinine","sodium","potassium","haemoglobin","packed_cell_volume","white_blood_cell_count",
            "red_blood_cell_count","hypertension","diabetes_mellitus","coronary_artery_disease","appetite","peda_edema","anemia","class"]

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_level', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'anemia', 'class'],
#       dtype='object')

# %%
df.describe()
# Out:
#               age  blood_pressure  specific_gravity     albumin       sugar  \
# count  391.000000      388.000000        353.000000  354.000000  351.000000
# mean    51.483376       76.469072          1.017408    1.016949    0.450142
# std     17.169714       13.683637          0.005717    1.352679    1.099191
# min      2.000000       50.000000          1.005000    0.000000    0.000000
# 25%     42.000000       70.000000          1.010000    0.000000    0.000000
# 50%     55.000000       80.000000          1.020000    0.000000    0.000000
# 75%     64.500000       80.000000          1.020000    2.000000    0.000000
# max     90.000000      180.000000          1.025000    5.000000    5.000000
#
#        blood_glucose_level  blood_urea  serum_creatinine      sodium  \
# count           356.000000  381.000000        383.000000  313.000000
# mean            148.036517   57.425722          3.072454  137.528754
# std              79.281714   50.503006          5.741126   10.408752
# ...

# %%
df.packed_cell_volume.unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', nan,
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '\t?', '52',
#        '14', '22', '18', '42', '17', '46', '23', '19', '25', '41', '26',
#        '15', '21', '43', '20', '\t43', '47', '9', '49', '50', '53', '51',
#        '54'], dtype=object)

# %%
df["packed_cell_volume"]=pd.to_numeric(df["packed_cell_volume"],errors="coerce")

# %%
df["white_blood_cell_count"]=pd.to_numeric(df["white_blood_cell_count"],errors="coerce")

# %%
df["red_blood_cell_count"]=pd.to_numeric(df["red_blood_cell_count"],errors="coerce")

# %%
df.dtypes
# Out:
# age                        float64
# blood_pressure             float64
# specific_gravity           float64
# albumin                    float64
# sugar                      float64
# red_blood_cells             object
# pus_cell                    object
# pus_cell_clumps             object
# bacteria                    object
# blood_glucose_level        float64
# blood_urea                 float64
# serum_creatinine           float64
# sodium                     float64
# potassium                  float64
# haemoglobin                float64
# packed_cell_volume         float64
# white_blood_cell_count     float64
# red_blood_cell_count       float64
# hypertension                object
# diabetes_mellitus           object
# coronary_artery_disease     object
# appetite                    object
# peda_edema                  object
# anemia                      object
# class                       object
# dtype: object

# %%
cat_cols=[col for col in df.columns if df[col].dtype=="object"]

# %%
cat_cols
# Out:
# ['red_blood_cells',
#  'pus_cell',
#  'pus_cell_clumps',
#  'bacteria',
#  'hypertension',
#  'diabetes_mellitus',
#  'coronary_artery_disease',
#  'appetite',
#  'peda_edema',
#  'anemia',
#  'class']

# %%
num_cols=[col for col in df.columns if df[col].dtype!="object"]

# %%
num_cols
# Out:
# ['age',
#  'blood_pressure',
#  'specific_gravity',
#  'albumin',
#  'sugar',
#  'blood_glucose_level',
#  'blood_urea',
#  'serum_creatinine',
#  'sodium',
#  'potassium',
#  'haemoglobin',
#  'packed_cell_volume',
#  'white_blood_cell_count',
#  'red_blood_cell_count']

# %%
# Getting all unique values of cat cols
for col in cat_cols:
  print(f"{col} has {df[col].unique()} values \n")
# Out:
# red_blood_cells has [nan 'normal' 'abnormal'] values
#
# pus_cell has ['normal' 'abnormal' nan] values
#
# pus_cell_clumps has ['notpresent' 'present' nan] values
#
# bacteria has ['notpresent' 'present' nan] values
#
# hypertension has ['yes' 'no' nan] values
#
# diabetes_mellitus has ['yes' 'no' ' yes' '\tno' '\tyes' nan] values
#
# coronary_artery_disease has ['no' 'yes' '\tno' nan] values
#
# appetite has ['good' 'poor' nan] values
#
# peda_edema has ['no' 'yes' nan] values
#
# anemia has ['no' 'yes' nan] values
#
# class has ['ckd' 'ckd\t' 'notckd'] values

# %%
df["diabetes_mellitus"].replace(to_replace={" yes":"yes",'\tno':"no",'\tyes':"yes"},inplace=True)

# %%
df["diabetes_mellitus"].unique()
# Out:
# array(['yes', 'no', nan], dtype=object)

# %%
df["coronary_artery_disease"].replace(to_replace={'\tno':"no"},inplace=True)
df["class"].replace(to_replace={'ckd\t':"ckd"},inplace=True)

# %%
for col in cat_cols:
  print(f"{col} has {df[col].unique()} values \n")
# Out:
# red_blood_cells has [nan 'normal' 'abnormal'] values
#
# pus_cell has ['normal' 'abnormal' nan] values
#
# pus_cell_clumps has ['notpresent' 'present' nan] values
#
# bacteria has ['notpresent' 'present' nan] values
#
# hypertension has ['yes' 'no' nan] values
#
# diabetes_mellitus has ['yes' 'no' nan] values
#
# coronary_artery_disease has ['no' 'yes' nan] values
#
# appetite has ['good' 'poor' nan] values
#
# peda_edema has ['no' 'yes' nan] values
#
# anemia has ['no' 'yes' nan] values
#
# class has ['ckd' 'notckd'] values

# %%
df["class"]=df["class"].map({'ckd':1 , 'notckd':0})

# %%
df["class"].unique()
# Out:
# array([1, 0])

# %%
# STARTING UNIVARIATE ANALYSIS -1 FEATURE AT A TIME

# %%
plt.figure(figsize=(10,6))
sns.histplot(df["age"].dropna(),kde=True,bins=20,color="r")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
# insights - age column is left skewed data

# %%
sns.countplot(x="hypertension",data=df,palette="pastel")
# Out:
# <Axes: xlabel='hypertension', ylabel='count'>

# %%
sns.boxplot(x="class",y="blood_urea",data=df,palette="viridis")
# Out:
# <Axes: xlabel='class', ylabel='blood_urea'>

# %%
'''
insights :
People with kidney disease has higher blood urea
People with kidney disease have higher median of blood urea'''
# Out:
# '\ninsights :\nPeople with kidney disease has higher blood urea\nPeople with kidney disease have higher median of blood urea'

# %%
sns.violinplot(x="class",y="serum_creatinine",data=df,palette="pastel")
# Out:
# <Axes: xlabel='class', ylabel='serum_creatinine'>

# %%
# insights - the tail of class 1 is longer so peaople with kidney disease has higher serum_creatinine and it has some outliers

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_level', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'anemia', 'class'],
#       dtype='object')

# %%
sns.countplot(x="anemia",data=df,palette="viridis")
# Out:
# <Axes: xlabel='anemia', ylabel='count'>

# %%
df.appetite.value_counts().plot.pie(autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df.appetite.value_counts().plot.pie(autopct="%1.1f%%",colors=["green","red"],startangle=90,explode=(0,0.1),shadow=True)
# Out:
# <Axes: ylabel='count'>

# %%
sns.histplot(df["white_blood_cell_count"].dropna(),bins=20,kde=True,color="darkorange")
# Out:
# <Axes: xlabel='white_blood_cell_count', ylabel='Count'>

# %%
df["diabetes_mellitus"].value_counts().plot.pie(autopct="%1.1f%%",colors=["red","yellow"],wedgeprops=dict(width=0.5),startangle=90,explode=(0,0.1))
# Out:
# <Axes: ylabel='count'>

# %%
# Bivariate plot
sns.scatterplot(x="age",y="blood_pressure",data=df)
# Out:
# <Axes: xlabel='age', ylabel='blood_pressure'>

# %%
sns.scatterplot(x="age",y="blood_pressure",data=df,hue="class",palette="coolwarm")
# Out:
# <Axes: xlabel='age', ylabel='blood_pressure'>

# %%
sns.boxplot(x="diabetes_mellitus",y="albumin",data=df,palette="viridis")
# Out:
# <Axes: xlabel='diabetes_mellitus', ylabel='albumin'>

# %%
sns.violinplot(x="diabetes_mellitus",y="albumin",data=df,palette="viridis",inner="quartile")
# Out:
# <Axes: xlabel='diabetes_mellitus', ylabel='albumin'>

# %%
# If violin plot is streched then it had outliers

# %%
# Stacked bar chat >> diabetes_mellitus and hypertension
pd.crosstab(df["diabetes_mellitus"],df["hypertension"])
# crosstab summarises the data
# Out:
# hypertension        no  yes
# diabetes_mellitus
# no                 220   41
# yes                 31  106

# %%
d_h=pd.crosstab(df["diabetes_mellitus"],df["hypertension"])
d_h.plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='diabetes_mellitus'>

# %%
# Multivariate analysis

# %%
cols=["age","blood_pressure","blood_glucose_level","serum_creatinine","class"]
df[cols]
# Out:
#       age  blood_pressure  blood_glucose_level  serum_creatinine  class
# 0    48.0            80.0                121.0               1.2      1
# 1     7.0            50.0                  NaN               0.8      1
# 2    62.0            80.0                423.0               1.8      1
# 3    48.0            70.0                117.0               3.8      1
# 4    51.0            80.0                106.0               1.4      1
# ..    ...             ...                  ...               ...    ...
# 395  55.0            80.0                140.0               0.5      0
# 396  42.0            70.0                 75.0               1.2      0
# 397  12.0            80.0                100.0               0.6      0
# 398  17.0            60.0                114.0               1.0      0
# 399  58.0            80.0                131.0               1.1      0
#
# [400 rows x 5 columns]

# %%
# Customised Pairplot
g=sns.PairGrid(df[cols],hue="class",palette="coolwarm")
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot,cmap="Blues_d")
g.map_diag(sns.histplot)
g.add_legend()
plt.title("Pairgrid for selected columns")
plt.show()

# %%
# Normal Pairplot
sns.pairplot(df[cols],hue="class",palette="husl")

# %%
# To see correlation value of numeric columns
df.corr(numeric_only=True)
# Out:
#                              age  blood_pressure  specific_gravity   albumin  \
# age                     1.000000        0.159480         -0.191096  0.122091
# blood_pressure          0.159480        1.000000         -0.218836  0.160689
# specific_gravity       -0.191096       -0.218836          1.000000 -0.469760
# albumin                 0.122091        0.160689         -0.469760  1.000000
# sugar                   0.220866        0.222576         -0.296234  0.269305
# blood_glucose_level     0.244992        0.160193         -0.374710  0.379464
# blood_urea              0.196985        0.188517         -0.314295  0.453528
# serum_creatinine        0.132531        0.146222         -0.361473  0.399198
# sodium                 -0.100046       -0.116422          0.412190 -0.459896
# potassium               0.058377        0.075151         -0.072787  0.129038
# haemoglobin            -0.192928       -0.306540          0.602582 -0.634632
# ...

# %%
# Heatmap
cor=df.corr(numeric_only=True)
plt.figure(figsize=(12,8))
sns.heatmap(cor,annot=True,cmap="coolwarm",linewidth=0.5)
# Out:
# <Axes: >

# %%
sns.swarmplot(x="diabetes_mellitus",y="age",hue="hypertension",data=df,palette="pastel",size=7)
# Out:
# <Axes: xlabel='diabetes_mellitus', ylabel='age'>

# %%
med=df[num_cols].median()
df[num_cols]=df[num_cols].fillna(med)

# %%
mod = df[cat_cols].mode().iloc[0]  # Select the first mode for each column
df[cat_cols] = df[cat_cols].fillna(mod)

# %%
df.isna().sum()
# Out:
# age                        0
# blood_pressure             0
# specific_gravity           0
# albumin                    0
# sugar                      0
# red_blood_cells            0
# pus_cell                   0
# pus_cell_clumps            0
# bacteria                   0
# blood_glucose_level        0
# blood_urea                 0
# serum_creatinine           0
# sodium                     0
# potassium                  0
# haemoglobin                0
# packed_cell_volume         0
# white_blood_cell_count     0
# red_blood_cell_count       0
# hypertension               0
# diabetes_mellitus          0
# coronary_artery_disease    0
# appetite                   0
# peda_edema                 0
# anemia                     0
# class                      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      400 non-null    float64
#  1   blood_pressure           400 non-null    float64
#  2   specific_gravity         400 non-null    float64
#  3   albumin                  400 non-null    float64
#  4   sugar                    400 non-null    float64
#  5   red_blood_cells          249 non-null    object
#  6   pus_cell                 335 non-null    object
#  7   pus_cell_clumps          396 non-null    object
#  8   bacteria                 396 non-null    object
#  9   blood_glucose_level      400 non-null    float64
#  10  blood_urea               400 non-null    float64
#  11  serum_creatinine         400 non-null    float64
#  12  sodium                   400 non-null    float64
#  13  potassium                400 non-null    float64
# ...

# %%
# Converting categorical columns to numeric using DATA ENCODING
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
for col in cat_cols:
  df[col]=label_encoder.fit_transform(df[col])

# %%
df.dtypes
# Out:
# age                        float64
# blood_pressure             float64
# specific_gravity           float64
# albumin                    float64
# sugar                      float64
# red_blood_cells              int64
# pus_cell                     int64
# pus_cell_clumps              int64
# bacteria                     int64
# blood_glucose_level        float64
# blood_urea                 float64
# serum_creatinine           float64
# sodium                     float64
# potassium                  float64
# haemoglobin                float64
# packed_cell_volume         float64
# white_blood_cell_count     float64
# red_blood_cell_count       float64
# hypertension                 int64
# diabetes_mellitus            int64
# coronary_artery_disease      int64
# appetite                     int64
# peda_edema                   int64
# anemia                       int64
# class                        int64
# dtype: object
